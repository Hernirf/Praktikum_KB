# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# nama_coklat=list(df['bar_name'])

# %%
df = pd.read_csv("chocolate_bars.csv")
df.head(150)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2530 entries, 0 to 2529
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2530 non-null   int64
#  1   manufacturer      2530 non-null   object
#  2   company_location  2530 non-null   object
#  3   year_reviewed     2530 non-null   int64
#  4   bean_origin       2530 non-null   object
#  5   bar_name          2530 non-null   object
#  6   cocoa_percent     2530 non-null   float64
#  7   num_ingredients   2443 non-null   float64
#  8   ingredients       2443 non-null   object
#  9   review            2530 non-null   object
#  10  rating            2530 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 217.5+ KB

# %%
# rating=list(df['rating'])

# %%
# plt.hist(rating)
# plt.show()

# persen=df.groupby(['cocoa_percent'])['year_reviewed'].sum()

plt.figure(figsize=(5,6))
# plot.hist(df['rating'])
df['cocoa_percent'].plot.hist()
# dp.plot.hist(stacked=true)
plt.show()

# %%
years = df.dropna(subset=['year_reviewed']).sort_values(by=['year_reviewed'])['year_reviewed'].unique()

sales = df.groupby(['year_reviewed'])['id'].sum()
persen=df.groupby(['year_reviewed'])['cocoa_percent'].sum()

plt.plot(years, sales, color='blue')
# plt.plot(years, persen, color='red')
plt.grid()
# plt.title('Penjualan Video Game Per Tahun')
# plt.xlabel('Tahun', fontsize=12)
# plt.ylabel('Penjualan (juta)', fontsize=12)
# plt.fill_between(years, sales, color='lightblue')


plt.show()

# %%
# plt.figure()
# company=list(df['company_location'])
# plot.pie(company, labels=company)
# # dp.plot.hist(stacked=true)
# plt.show()

dataplotting = df.sort_values("company_location").head(100)

company = dataplotting.dropna(subset=['company_location']).sort_values(by=['company_location'])['company_location'].unique()
# sales = df.groupby(['ingredients'])['company_location'].sum()

total = dataplotting.groupby(['company_location'])['bar_name'].count()
plt.pie(total, labels=company, autopct='%.1f%%')
plt.title('Total Video Game Berdasarkan Genre')
plt.show()

# %%
company = df.dropna(subset=['year_reviewed']).sort_values(by=['year_reviewed'])['year_reviewed'].unique()
# sales = df.groupby(['ingredients'])['company_location'].sum()

plt.figure(figsize=(10,6))
total = df.groupby(['year_reviewed'])['rating'].count()
plt.pie(total,labels=company,autopct='%.1f%%')
plt.title('Total Video Game Berdasarkan Genre')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [116], line 6
#       4 plt.figure(figsize=(10,6))
#       5 total = df.groupby(['cocoa_percent'])['year_reviewed'].count()
# ----> 6 plt.pie(total,labels=company,autopct='%.1f%%')
#       7 plt.title('Total Video Game Berdasarkan Genre')
#       8 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2715, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2708 @_copy_docstring_and_deprecators(Axes.pie)
#    2709 def pie(
#    2710         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2713         textprops=None, center=(0, 0), frame=False,
#    2714         rotatelabels=False, *, normalize=True, data=None):
# ...

# %%
# Out:
# U.S.A.                   1136
# Canada                    177
# France                    176
# U.K.                      133
# Italy                      78
#                          ...
# St.Vincent-Grenadines       1
# Martinique                  1
# Ghana                       1
# Wales                       1
# Suriname                    1
# Name: company_location, Length: 67, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [101], line 4
#       1 intervals = np.arange(50,100 , 5)
#       2 labels = np.vectorize(lambda x: f"{x}-{x +5}")(np.arange(50, 100, 5))
# ----> 4 reading_score_total = df.groupby(pd.cut(df["cocoa_percent"], intervals, labels=labels))["cocoa_percent"].count().to_list()
#       5 print(reading_score_total)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\tile.py:293, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     290     if (np.diff(bins.astype("float64")) < 0).any():
#     291         raise ValueError("bins must increase monotonically.")
# --> 293 fac, bins = _bins_to_cuts(
#     294     x,
#     295     bins,
#     296     right=right,
#     297     labels=labels,
#     298     precision=precision,
# ...
